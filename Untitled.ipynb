# %%
import streamlit as st
import pandas as pd

# Load the data
data = pd.read_csv("Red_Bus.csv")
df = pd.DataFrame(data)

# Streamlit app
st.header("Red Bus Filter App")

# Sidebar filters
st.sidebar.header('Filter Options')

# Filter by State_Name
state_name = st.sidebar.selectbox(
    'Select State Name',
    df['State_Name'].unique()
)

# Filter by Bus_Type
bus_type = st.sidebar.selectbox(
    'Select Bus Type',
    df['Bus_Type'].unique()
)

# Filter by Price
price_range = st.sidebar.slider(
    'Select Price Range',
    min_value=float(df['Price'].min()),
    max_value=float(df['Price'].max()),
    value=(float(df['Price'].min()), float(df['Price'].max()))
)

# Filter by Star_Rating
star_rating_range = st.sidebar.slider(
    'Select Star Rating',
    min_value=float(df['Star_Rating'].min()),
    max_value=float(df['Star_Rating'].max()),
    value=(float(df['Star_Rating'].min()), float(df['Star_Rating'].max())),
    step=0.1
)

# Apply filters
filtered_df = df[
    (df['State_Name'] == state_name) &
    (df['Bus_Type'] == bus_type) &
    (df['Price'] >= price_range[0]) &
    (df['Price'] <= price_range[1]) &
    (df['Star_Rating'] >= star_rating_range[0]) &
    (df['Star_Rating'] <= star_rating_range[1])
]

# Display the DataFrame
st.subheader('Filtered Results')
st.dataframe(filtered_df)

# Add a link to more details
st.sidebar.header('More Information')
st.sidebar.write('Click [here](https://www.redbus.in) to view more bus options on RedBus.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       6 df = pd.DataFrame(data)
#       8 # Streamlit app
# ----> 9 st.header("Red Bus Filter App")
#      11 # Sidebar filters
#      12 st.sidebar.header('Filter Options')
#
# AttributeError: module 'streamlit' has no attribute 'header'

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Using cached streamlit-1.36.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Using cached altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Using cached cachetools-5.4.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (10.3.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Using cached protobuf-5.27.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Using cached pyarrow-17.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (8.4.1)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\admin\miniconda3\lib\site-packages (from streamlit) (6.4)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Using cached watchdog-4.0.1-py3-none-win_amd64.whl.metadata (37 kB)
# Requirement already satisfied: jinja2 in c:\users\admin\miniconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\miniconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.21.1)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\admin\miniconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\miniconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\miniconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\miniconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\admin\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Using cached streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
# Using cached altair-5.3.0-py3-none-any.whl (857 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached cachetools-5.4.0-py3-none-any.whl (9.5 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached protobuf-5.27.2-cp310-abi3-win_amd64.whl (426 kB)
# Using cached pyarrow-17.0.0-cp312-cp312-win_amd64.whl (25.1 MB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached watchdog-4.0.1-py3-none-win_amd64.whl (83 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toolz, toml, smmap, pyarrow, protobuf, mdurl, cachetools, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
# Successfully installed altair-5.3.0 blinker-1.8.2 cachetools-5.4.0 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-5.27.2 pyarrow-17.0.0 pydeck-0.9.1 rich-13.7.1 smmap-5.0.1 streamlit-1.36.0 toml-0.10.2 toolz-0.12.1 watchdog-4.0.1
# Note: you may need to restart the kernel to use updated packages.
